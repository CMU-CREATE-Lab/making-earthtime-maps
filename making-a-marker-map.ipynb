# %%
# Data from Copyright © Global Energy Monitor. Distributed under a Creative Commons Attribution 4.0 International License.
# Recommended Citation: “Global Energy Monitor, Global Oil and Gas Extraction Tracker, March 2024 Release”. When the data set is being shared or adapted and our Creative Commons CC BY 4.0 International license applies, please read the license for attribution requirements. Necessary attribution elements are included in our data download files.
# https://globalenergymonitor.org/projects/global-oil-gas-extraction-tracker/

# %%
import pandas as pd
import geojson, json, os, random

class GoogleSheetRow():
    columns = [
        'Enabled', 'Share link identifier', 'Category', 'Name', 'Credits', 'Base layer', 'Custom slider ticks', 'Start date',
        'End date', 'Step', 'URL', 'Scaling', 'Color Scaling', 'Map Type', 'Color', 'External GeoJSON', 'Name Key', 'Show Graph',
        'Graph Title', 'Graph Plot Colors', 'Graph Plots First Visible', 'Graph X-Axis Label', 'Graph Y-Axis Label', 'Graph Y-Axis Min',
        'Graph Y-Axis Max', 'Graph X-Axis Label Interval', 'Legend Content', 'Legend Key', 'Load Data Function', 'Set Data Function', 
        'Number of Levels', 'Number of Attributes', 'Vertex Shader', 'Fragment Shader', 'Draw Function', 'Playback Rate',
        'Master Playback Rate', 'Colormap Src', 'Layer Description', 'Featured Themes', 'Draw Options', 'Set Data Options', 'Extras Options',
        'Draw Order', 'Timeline Type', 'Layer Constraints', 'Mapbox', 'Draw Layer Function'
    ]
    key_values = {}
    def __init__(self, _dict = {}):
        for column in self.columns:
            self.key_values[column] = ''
        for key in _dict.keys():
            if key in self.columns:
                self.key_values[key] = _dict[key]
    def set_column(self, key, value):
        if key in self.columns:
            self.key_values[key] = value
    def print_row(self):
        row = []
        for column in self.columns:
            row.append(self.key_values[column])
        print("\t".join(row))

# %%
fname = "../data/Global-Oil-and-Gas-Extraction-Tracker-March-2024.xlsx"
excel = pd.ExcelFile('../data/Global-Oil-and-Gas-Extraction-Tracker-March-2024.xlsx')

excel.sheet_names
# Out:
# ['Main data', 'Production & reserves', 'About']

# %%
df = pd.read_excel(excel, "Main data")

# %%
feature_collection = geojson.FeatureCollection(features=[])
max_value = 0
for idx, row in df.iterrows():
    if row['Status'] != 'operating' or pd.isna(row['Production start year']) or pd.isna(row['Latitude']):
        continue
    point = geojson.Point((row['Longitude'], row['Latitude']))
    # Why add a random month to start?
    #   We could be exact and just add the start year, but the visualization ends feeling chunky
    #   Adding a somewhat staggered random start to each inidvidual location makes it seem nicer
    #   Just opinions though. Do w/e you want and pick what you like best
    random_month = random.randrange(1,12)
    random_pad_1 = str(random_month).zfill(2) + '01'    
    random_pad_2 = str(random_month+1).zfill(2) + '01'    

    dates = [str(int(row['Production start year']))+random_pad_1, str(int(row['Production start year']))+random_pad_2, '20240101']
    values = [0,100,100]
    properties = {
        'status': 'operating',
        'timeseries': {
            'dates': dates,
            'values': values
        }
        
    }
    feature = geojson.Feature(geometry=point, properties=properties)
    feature_collection['features'].append(feature)

# %%
oname = 'data/making_a_marker_map_example_1.geojson'
os.makedirs(os.path.dirname(oname), exist_ok=True)
with open(oname, 'w') as f:
    json.dump(feature_collection, f)

# %%
# Copy the data somewhere www accessible
#!scp data/making_a_marker_map_example_1.geojson timemachine2:/t/earthtime.org/app/data/making-earthtime-maps
# !scp data/making_a_marker_map_example_1.geojson /t/earthtime.org/app/data/making-earthtime-maps
# Out:
# cp: cannot create regular file '/t/earthtime.org/app/data/making-earthtime-maps/making_a_marker_map_example_1.geojson': Permission denied

# %%
# Please try to always add a layer description with minimally a brief explanation of what the visualization shows 
#  and where the data came from.
layer_description = "<h2>Oil and Gas Extraction Sites</h2><p>Sourced from <a href=\"https://globalenergymonitor.org/projects/global-oil-gas-extraction-tracker/\">https://globalenergymonitor.org/projects/global-oil-gas-extraction-tracker/</a></p><p>Displaying operating oil and gas extraction sites.</p>"
# Share link identifiers should be unique. Would be great if a DB just handled this... 
share_link_identifer = 'making_a_marker_map_example_1_' + str(random.getrandbits(16))
category = 'Making EarthTime Maps'
name = 'Oil and Gas Extraction Sites'
# This should be wherever yoou uploaded your data to
url = 'https://tiles.earthtime.org/making-earthtime-maps/making_a_marker_map_example_1.geojson'
layer_args = {
    'Enabled': 'TRUE',
    'Share link identifier': share_link_identifer,
    'Category': category, 
    'Name': name, 
    'Credits': 'Global Energy Monitor', 
    'Base layer': 'mb_openplanetv1', 
    'Start date': '1900',
    'End date': '2024', 
    'URL': url, 
    'Scaling': f'd3.scaleSqrt().domain([0,100]).range([0,10]).clamp(true)', 
    'Layer Description': layer_description,
    'Map Type': 'marker',
    'Load Data Function': 'WebGLVectorTile2.prototype._loadGeojsonData',
    'Set Data Function': 'WebGLVectorTile2.prototype._setMarkerData',
    'Number of Attributes': '14',
    'Vertex Shader': 'WebGLVectorTile2.animatedMarkerVertexShader',
    'Fragment Shader': 'WebGLVectorTile2.markerFragmentShader',
    'Draw Function': 'WebGLVectorTile2.prototype._drawMarker', 
    'Draw Options': '{"pointSize": 10, "linewidth": 2, "mode": "disc"}',
    'Set Data Options': '{ "sizeKey": "timeseries", "fills": [[250, 242, 232, 0.55]], "strokes": [[250, 242, 232, 0.75]]}',
    'Draw Order': '700',
}
row = GoogleSheetRow(layer_args)

# %%
# C&P the output of this into a sheet. Would be cool if this just like happened...
row.print_row()
# Out:
# TRUE	making_a_marker_map_example_1_16805	Making EarthTime Maps	Oil and Gas Extraction Sites	Global Energy Monitor	mb_openplanetv1		1900	2024		https://tiles.earthtime.org/making-earthtime-maps/making_a_marker_map_example_1.geojson	d3.scaleSqrt().domain([0,100]).range([0,10]).clamp(true)		marker															WebGLVectorTile2.prototype._loadGeojsonData	WebGLVectorTile2.prototype._setMarkerData		14	WebGLVectorTile2.animatedMarkerVertexShader	WebGLVectorTile2.markerFragmentShader	WebGLVectorTile2.prototype._drawMarker				<h2>Oil and Gas Extraction Sites</h2><p>Sourced from <a href="https://globalenergymonitor.org/projects/global-oil-gas-extraction-tracker/">https://globalenergymonitor.org/projects/global-oil-gas-extraction-tracker/</a></p><p>Displaying operating oil and gas extraction sites.</p>		{"pointSize": 10, "linewidth": 2, "mode": "disc"}	{ "sizeKey": "timeseries", "fills": [[250, 242, 232, 0.55]], "strokes": [[250, 242, 232, 0.75]]}		700

# %%
fname2 = "../data/FloodArchive.xlsx"
excel2 = pd.ExcelFile('../data/FloodArchive.xlsx')

excel2.sheet_names
# Out:
# ['Sheet 1']

# %%
df2 = pd.read_excel(excel2)

print(df2)
# Out:
#         ID  GlideNumber      Country OtherCountry  Longitude  Latitude  \
# 0        1          0.0      Algeria            0    5.23026  35.81420
# 1        2          0.0       Brazil            0  -45.34890 -18.71110
# 2        3          0.0  Phillipines            0  122.97400  10.02070
# 3        4          0.0    Indonesia            0  124.60600   1.01489
# 4        5          0.0   Mozambique            0   32.34910 -25.86930
# ...    ...          ...          ...          ...        ...       ...
# 5125  5127          NaN     Thailand          NaN  101.32300  17.32040
# 5126  5128          NaN          USA          NaN  -86.62910  32.49010
# 5127  5129          NaN       Mexico          NaN -100.83200  19.95080
# 5128  5130          NaN        India          NaN   87.96100  23.79840
# 5129  5131          NaN        Italy          NaN    9.37570  44.63930
#
#            Area  Began  Ended Validation  Dead  Displaced  \
# 0      92615.67   1985   1985       News    26       3000
# 1     678498.82   1985   1985       News   229      80000
# 2      12846.03   1985   1985       News    43        444
# 3      16542.12   1985   1985       News    21        300
# 4      20082.21   1985   1985       News    19          0
# ...         ...    ...    ...        ...   ...        ...
# 5125  218554.79   2021   2021  FloodList     0      40000
# 5126   35416.48   2021   2021  FloodList     4          0
# 5127   69141.86   2021   2021  FloodList     4       2440
# 5128   42828.60   2021   2021  FloodList    11     500000
# 5129   10408.23   2021   2021  FloodList     0          0
#
#                   MainCause  Severity
# 0                Heavy rain       1.0
# 1                Heavy rain       2.0
# 2           Torrential rain       1.0
# 3           Torrential rain       1.0
# 4                Heavy rain       2.0
# ...                     ...       ...
# 5125  Tropical Storm Dianmu       1.5
# 5126        Torrential Rain       1.5
# 5127             Heavy Rain       1.5
# 5128         Monsoonal Rain       1.5
# 5129        Torrential Rain       1.5
#
# [5130 rows x 14 columns]

# %%
feature_collection2 = geojson.FeatureCollection(features=[])
max_value = 0
for idx, row in df2.iterrows():
    if pd.isna(row['Began']) or pd.isna(row['Latitude']):
        continue
    point = geojson.Point((row['Longitude'], row['Latitude']))

    dates = [str(int(row['Began'])), str(int(row['Began'])), '2021']
    values = [0,100,100]
    properties = {
        'timeseries': {
            'dates': dates,
            'values': values
        }
        
    }
    feature = geojson.Feature(geometry=point, properties=properties)
    print(feature)
    feature_collection2['features'].append(feature)
# Out:
# {"geometry": {"coordinates": [5.23026, 35.8142], "type": "Point"}, "properties": {"timeseries": {"dates": ["1985", "1985", "2021"], "values": [0, 100, 100]}}, "type": "Feature"}
# {"geometry": {"coordinates": [-45.3489, -18.7111], "type": "Point"}, "properties": {"timeseries": {"dates": ["1985", "1985", "2021"], "values": [0, 100, 100]}}, "type": "Feature"}
# {"geometry": {"coordinates": [122.974, 10.0207], "type": "Point"}, "properties": {"timeseries": {"dates": ["1985", "1985", "2021"], "values": [0, 100, 100]}}, "type": "Feature"}
# {"geometry": {"coordinates": [124.606, 1.01489], "type": "Point"}, "properties": {"timeseries": {"dates": ["1985", "1985", "2021"], "values": [0, 100, 100]}}, "type": "Feature"}
# {"geometry": {"coordinates": [32.3491, -25.8693], "type": "Point"}, "properties": {"timeseries": {"dates": ["1985", "1985", "2021"], "values": [0, 100, 100]}}, "type": "Feature"}
# {"geometry": {"coordinates": [43.36, -11.6516], "type": "Point"}, "properties": {"timeseries": {"dates": ["1985", "1985", "2021"], "values": [0, 100, 100]}}, "type": "Feature"}
# {"geometry": {"coordinates": [175.734, -37.2305], "type": "Point"}, "properties": {"timeseries": {"dates": ["1985", "1985", "2021"], "values": [0, 100, 100]}}, "type": "Feature"}
# {"geometry": {"coordinates": [108.14, -7.04008], "type": "Point"}, "properties": {"timeseries": {"dates": ["1985", "1985", "2021"], "values": [0, 100, 100]}}, "type": "Feature"}
# {"geometry": {"coordinates": [-85.1742, 40.6691], "type": "Point"}, "properties": {"timeseries": {"dates": ["1985", "1985", "2021"], "values": [0, 100, 100]}}, "type": "Feature"}
# {"geometry": {"coordinates": [-63.2887, -21.2244], "type": "Point"}, "properties": {"timeseries": {"dates": ["1985", "1985", "2021"], "values": [0, 100, 100]}}, "type": "Feature"}
# {"geometry": {"coordinates": [-89.5537, 40.6814], "type": "Point"}, "properties": {"timeseries": {"dates": ["1985", "1985", "2021"], "values": [0, 100, 100]}}, "type": "Feature"}
# {"geometry": {"coordinates": [-108.093, 35.3824], "type": "Point"}, "properties": {"timeseries": {"dates": ["1985", "1985", "2021"], "values": [0, 100, 100]}}, "type": "Feature"}
# {"geometry": {"coordinates": [-96.7845, 29.6044], "type": "Point"}, "properties": {"timeseries": {"dates": ["1985", "1985", "2021"], "values": [0, 100, 100]}}, "type": "Feature"}
# {"geometry": {"coordinates": [-83.5377, 42.0122], "type": "Point"}, "properties": {"timeseries": {"dates": ["1985", "1985", "2021"], "values": [0, 100, 100]}}, "type": "Feature"}
# {"geometry": {"coordinates": [-48.0987, -4.13519], "type": "Point"}, "properties": {"timeseries": {"dates": ["1985", "1985", "2021"], "values": [0, 100, 100]}}, "type": "Feature"}
# {"geometry": {"coordinates": [-96.8425, 28.5802], "type": "Point"}, "properties": {"timeseries": {"dates": ["1985", "1985", "2021"], "values": [0, 100, 100]}}, "type": "Feature"}
# {"geometry": {"coordinates": [127.897, 48.0917], "type": "Point"}, "properties": {"timeseries": {"dates": ["1985", "1985", "2021"], "values": [0, 100, 100]}}, "type": "Feature"}
# {"geometry": {"coordinates": [-87.8805, 46.4938], "type": "Point"}, "properties": {"timeseries": {"dates": ["1985", "1985", "2021"], "values": [0, 100, 100]}}, "type": "Feature"}
# {"geometry": {"coordinates": [-105.275, 34.8628], "type": "Point"}, "properties": {"timeseries": {"dates": ["1985", "1985", "2021"], "values": [0, 100, 100]}}, "type": "Feature"}
# {"geometry": {"coordinates": [-66.706, 18.2291], "type": "Point"}, "properties": {"timeseries": {"dates": ["1985", "1985", "2021"], "values": [0, 100, 100]}}, "type": "Feature"}
# {"geometry": {"coordinates": [109.57, 25.6694], "type": "Point"}, "properties": {"timeseries": {"dates": ["1985", "1985", "2021"], "values": [0, 100, 100]}}, "type": "Feature"}
# {"geometry": {"coordinates": [-58.9735, -35.4392], "type": "Point"}, "properties": {"timeseries": {"dates": ["1985", "1985", "2021"], "values": [0, 100, 100]}}, "type": "Feature"}
# {"geometry": {"coordinates": [91.8542, 24.6497], "type": "Point"}, "properties": {"timeseries": {"dates": ["1985", "1985", "2021"], "values": [0, 100, 100]}}, "type": "Feature"}
# {"geometry": {"coordinates": [-99.4494, 33.6977], "type": "Point"}, "properties": {"timeseries": {"dates": ["1985", "1985", "2021"], "values": [0, 100, 100]}}, "type": "Feature"}
# {"geometry": {"coordinates": [-96.1011, 36.3581], "type": "Point"}, "properties": {"timeseries": {"dates": ["1985", "1985", "2021"], "values": [0, 100, 100]}}, "type": "Feature"}
# {"geometry": {"coordinates": [120.916, 14.7417], "type": "Point"}, "properties": {"timeseries": {"dates": ["1985", "1985", "2021"], "values": [0, 100, 100]}}, "type": "Feature"}
# {"geometry": {"coordinates": [75.0937, 14.5398], "type": "Point"}, "properties": {"timeseries": {"dates": ["1985", "1985", "2021"], "values": [0, 100, 100]}}, "type": "Feature"}
# {"geometry": {"coordinates": [109.974, 27.7882], "type": "Point"}, "properties": {"timeseries": {"dates": ["1985", "1985", "2021"], "values": [0, 100, 100]}}, "type": "Feature"}
# {"geometry": {"coordinates": [89.9853, 22.6176], "type": "Point"}, "properties": {"timeseries": {"dates": ["1985", "1985", "2021"], "values": [0, 100, 100]}}, "type": "Feature"}
# {"geometry": {"coordinates": [6.50952, 50.7134], "type": "Point"}, "properties": {"timeseries": {"dates": ["1985", "1985", "2021"], "values": [0, 100, 100]}}, "type": "Feature"}
# {"geometry": {"coordinates": [-80.5923, 38.9381], "type": "Point"}, "properties": {"timeseries": {"dates": ["1985", "1985", "2021"], "values": [0, 100, 100]}}, "type": "Feature"}
# {"geometry": {"coordinates": [21.5509, 11.6727], "type": "Point"}, "properties": {"timeseries": {"dates": ["1985", "1985", "2021"], "values": [0, 100, 100]}}, "type": "Feature"}
# {"geometry": {"coordinates": [76.9103, 32.8353], "type": "Point"}, "properties": {"timeseries": {"dates": ["1985", "1985", "2021"], "values": [0, 100, 100]}}, "type": "Feature"}
# {"geometry": {"coordinates": [24.9139, 13.489], "type": "Point"}, "properties": {"timeseries": {"dates": ["1985", "1985", "2021"], "values": [0, 100, 100]}}, "type": "Feature"}
# {"geometry": {"coordinates": [125.156, 42.6953], "type": "Point"}, "properties": {"timeseries": {"dates": ["1985", "1985", "2021"], "values": [0, 100, 100]}}, "type": "Feature"}
# {"geometry": {"coordinates": [90.1999, 23.1028], "type": "Point"}, "properties": {"timeseries": {"dates": ["1985", "1985", "2021"], "values": [0, 100, 100]}}, "type": "Feature"}
# {"geometry": {"coordinates": [-85.7798, 34.4872], "type": "Point"}, "properties": {"timeseries": {"dates": ["1985", "1985", "2021"], "values": [0, 100, 100]}}, "type": "Feature"}
# {"geometry": {"coordinates": [120.376, 31.5112], "type": "Point"}, "properties": {"timeseries": {"dates": ["1985", "1985", "2021"], "values": [0, 100, 100]}}, "type": "Feature"}
# {"geometry": {"coordinates": [-105.091, 41.6853], "type": "Point"}, "properties": {"timeseries": {"dates": ["1985", "1985", "2021"], "values": [0, 100, 100]}}, "type": "Feature"}
# {"geometry": {"coordinates": [87.1258, 27.5049], "type": "Point"}, "properties": {"timeseries": {"dates": ["1985", "1985", "2021"], "values": [0, 100, 100]}}, "type": "Feature"}
# {"geometry": {"coordinates": [100.797, 23.5255], "type": "Point"}, "properties": {"timeseries": {"dates": ["1985", "1985", "2021"], "values": [0, 100, 100]}}, "type": "Feature"}
# {"geometry": {"coordinates": [12.2066, 47.3155], "type": "Point"}, "properties": {"timeseries": {"dates": ["1985", "1985", "2021"], "values": [0, 100, 100]}}, "type": "Feature"}
# {"geometry": {"coordinates": [39.7851, 11.0514], "type": "Point"}, "properties": {"timeseries": {"dates": ["1985", "1985", "2021"], "values": [0, 100, 100]}}, "type": "Feature"}
# {"geometry": {"coordinates": [111.342, 25.3728], "type": "Point"}, "properties": {"timeseries": {"dates": ["1985", "1985", "2021"], "values": [0, 100, 100]}}, "type": "Feature"}
# {"geometry": {"coordinates": [109.825, 21.6782], "type": "Point"}, "properties": {"timeseries": {"dates": ["1985", "1985", "2021"], "values": [0, 100, 100]}}, "type": "Feature"}
# {"geometry": {"coordinates": [-82.3489, 28.5438], "type": "Point"}, "properties": {"timeseries": {"dates": ["1985", "1985", "2021"], "values": [0, 100, 100]}}, "type": "Feature"}
# {"geometry": {"coordinates": [142.796, 43.4577], "type": "Point"}, "properties": {"timeseries": {"dates": ["1985", "1985", "2021"], "values": [0, 100, 100]}}, "type": "Feature"}
# {"geometry": {"coordinates": [110.542, 21.0725], "type": "Point"}, "properties": {"timeseries": {"dates": ["1985", "1985", "2021"], "values": [0, 100, 100]}}, "type": "Feature"}
# {"geometry": {"coordinates": [86.3518, 27.3195], "type": "Point"}, "properties": {"timeseries": {"dates": ["1985", "1985", "2021"], "values": [0, 100, 100]}}, "type": "Feature"}
# {"geometry": {"coordinates": [-83.8824, 43.242], "type": "Point"}, "properties": {"timeseries": {"dates": ["1985", "1985", "2021"], "values": [0, 100, 100]}}, "type": "Feature"}
# {"geometry": {"coordinates": [106.251, 20.8454], "type": "Point"}, "properties": {"timeseries": {"dates": ["1985", "1985", "2021"], "values": [0, 100, 100]}}, "type": "Feature"}
# {"geometry": {"coordinates": [15.9425, 63.1724], "type": "Point"}, "properties": {"timeseries": {"dates": ["1985", "1985", "2021"], "values": [0, 100, 100]}}, "type": "Feature"}
# {"geometry": {"coordinates": [82.8434, 26.4816], "type": "Point"}, "properties": {"timeseries": {"dates": ["1985", "1985", "2021"], "values": [0, 100, 100]}}, "type": "Feature"}
# {"geometry": {"coordinates": [-71.7971, 18.8752], "type": "Point"}, "properties": {"timeseries": {"dates": ["1985", "1985", "2021"], "values": [0, 100, 100]}}, "type": "Feature"}
# {"geometry": {"coordinates": [6.50345, 6.41486], "type": "Point"}, "properties": {"timeseries": {"dates": ["1985", "1985", "2021"], "values": [0, 100, 100]}}, "type": "Feature"}
# {"geometry": {"coordinates": [89.6457, 24.7027], "type": "Point"}, "properties": {"timeseries": {"dates": ["1985", "1985", "2021"], "values": [0, 100, 100]}}, "type": "Feature"}
# {"geometry": {"coordinates": [-66.635, 18.2233], "type": "Point"}, "properties": {"timeseries": {"dates": ["1985", "1985", "2021"], "values": [0, 100, 100]}}, "type": "Feature"}
# {"geometry": {"coordinates": [-105.8, 33.1369], "type": "Point"}, "properties": {"timeseries": {"dates": ["1985", "1985", "2021"], "values": [0, 100, 100]}}, "type": "Feature"}
# {"geometry": {"coordinates": [2.17876, 7.37547], "type": "Point"}, "properties": {"timeseries": {"dates": ["1985", "1985", "2021"], "values": [0, 100, 100]}}, "type": "Feature"}
# {"geometry": {"coordinates": [99.6423, 12.9425], "type": "Point"}, "properties": {"timeseries": {"dates": ["1985", "1985", "2021"], "values": [0, 100, 100]}}, "type": "Feature"}
# {"geometry": {"coordinates": [86.7154, 21.1495], "type": "Point"}, "properties": {"timeseries": {"dates": ["1985", "1985", "2021"], "values": [0, 100, 100]}}, "type": "Feature"}
# {"geometry": {"coordinates": [-98.6949, 31.7526], "type": "Point"}, "properties": {"timeseries": {"dates": ["1985", "1985", "2021"], "values": [0, 100, 100]}}, "type": "Feature"}
# {"geometry": {"coordinates": [121.138, 16.1135], "type": "Point"}, "properties": {"timeseries": {"dates": ["1985", "1985", "2021"], "values": [0, 100, 100]}}, "type": "Feature"}
# {"geometry": {"coordinates": [-90.0003, 29.542], "type": "Point"}, "properties": {"timeseries": {"dates": ["1985", "1985", "2021"], "values": [0, 100, 100]}}, "type": "Feature"}
# {"geometry": {"coordinates": [-78.4543, 38.837], "type": "Point"}, "properties": {"timeseries": {"dates": ["1985", "1985", "2021"], "values": [0, 100, 100]}}, "type": "Feature"}
# {"geometry": {"coordinates": [-77.2692, 17.9531], "type": "Point"}, "properties": {"timeseries": {"dates": ["1985", "1985", "2021"], "values": [0, 100, 100]}}, "type": "Feature"}
# {"geometry": {"coordinates": [-67.0248, 10.1633], "type": "Point"}, "properties": {"timeseries": {"dates": ["1985", "1985", "2021"], "values": [0, 100, 100]}}, "type": "Feature"}
# {"geometry": {"coordinates": [-60.6243, 11.2699], "type": "Point"}, "properties": {"timeseries": {"dates": ["1985", "1985", "2021"], "values": [0, 100, 100]}}, "type": "Feature"}
# {"geometry": {"coordinates": [-82.8186, 42.6864], "type": "Point"}, "properties": {"timeseries": {"dates": ["1985", "1985", "2021"], "values": [0, 100, 100]}}, "type": "Feature"}
# {"geometry": {"coordinates": [-116.954, 44.0047], "type": "Point"}, "properties": {"timeseries": {"dates": ["1986", "1986", "2021"], "values": [0, 100, 100]}}, "type": "Feature"}
# {"geometry": {"coordinates": [-66.0628, -16.5525], "type": "Point"}, "properties": {"timeseries": {"dates": ["1986", "1986", "2021"], "values": [0, 100, 100]}}, "type": "Feature"}
# {"geometry": {"coordinates": [-121.38, 39.2816], "type": "Point"}, "properties": {"timeseries": {"dates": ["1986", "1986", "2021"], "values": [0, 100, 100]}}, "type": "Feature"}
# {"geometry": {"coordinates": [-69.0747, -16.1155], "type": "Point"}, "properties": {"timeseries": {"dates": ["1986", "1986", "2021"], "values": [0, 100, 100]}}, "type": "Feature"}
# {"geometry": {"coordinates": [-87.8814, 45.0248], "type": "Point"}, "properties": {"timeseries": {"dates": ["1986", "1986", "2021"], "values": [0, 100, 100]}}, "type": "Feature"}
# {"geometry": {"coordinates": [-59.5908, -29.4731], "type": "Point"}, "properties": {"timeseries": {"dates": ["1986", "1986", "2021"], "values": [0, 100, 100]}}, "type": "Feature"}
# {"geometry": {"coordinates": [-43.7954, -9.79844], "type": "Point"}, "properties": {"timeseries": {"dates": ["1986", "1986", "2021"], "values": [0, 100, 100]}}, "type": "Feature"}
# {"geometry": {"coordinates": [49.8267, 33.3427], "type": "Point"}, "properties": {"timeseries": {"dates": ["1986", "1986", "2021"], "values": [0, 100, 100]}}, "type": "Feature"}
# {"geometry": {"coordinates": [100.638, 15.0651], "type": "Point"}, "properties": {"timeseries": {"dates": ["1986", "1986", "2021"], "values": [0, 100, 100]}}, "type": "Feature"}
# {"geometry": {"coordinates": [-89.8357, 37.2733], "type": "Point"}, "properties": {"timeseries": {"dates": ["1986", "1986", "2021"], "values": [0, 100, 100]}}, "type": "Feature"}
# {"geometry": {"coordinates": [160.669, -9.33748], "type": "Point"}, "properties": {"timeseries": {"dates": ["1986", "1986", "2021"], "values": [0, 100, 100]}}, "type": "Feature"}
# {"geometry": {"coordinates": [-97.2966, 32.4344], "type": "Point"}, "properties": {"timeseries": {"dates": ["1986", "1986", "2021"], "values": [0, 100, 100]}}, "type": "Feature"}
# {"geometry": {"coordinates": [-71.0406, -33.0922], "type": "Point"}, "properties": {"timeseries": {"dates": ["1986", "1986", "2021"], "values": [0, 100, 100]}}, "type": "Feature"}
# {"geometry": {"coordinates": [-79.7424, 40.604], "type": "Point"}, "properties": {"timeseries": {"dates": ["1986", "1986", "2021"], "values": [0, 100, 100]}}, "type": "Feature"}
# {"geometry": {"coordinates": [-97.8369, 29.6932], "type": "Point"}, "properties": {"timeseries": {"dates": ["1986", "1986", "2021"], "values": [0, 100, 100]}}, "type": "Feature"}
# {"geometry": {"coordinates": [-76.2478, 20.8066], "type": "Point"}, "properties": {"timeseries": {"dates": ["1986", "1986", "2021"], "values": [0, 100, 100]}}, "type": "Feature"}
# {"geometry": {"coordinates": [-71.0406, -33.0922], "type": "Point"}, "properties": {"timeseries": {"dates": ["1986", "1986", "2021"], "values": [0, 100, 100]}}, "type": "Feature"}
# {"geometry": {"coordinates": [-94.1582, 31.1451], "type": "Point"}, "properties": {"timeseries": {"dates": ["1986", "1986", "2021"], "values": [0, 100, 100]}}, "type": "Feature"}
# {"geometry": {"coordinates": [-94.9169, 41.7178], "type": "Point"}, "properties": {"timeseries": {"dates": ["1986", "1986", "2021"], "values": [0, 100, 100]}}, "type": "Feature"}
# {"geometry": {"coordinates": [120.905, 15.6456], "type": "Point"}, "properties": {"timeseries": {"dates": ["1986", "1986", "2021"], "values": [0, 100, 100]}}, "type": "Feature"}
# {"geometry": {"coordinates": [-70.2357, 2.12719], "type": "Point"}, "properties": {"timeseries": {"dates": ["1986", "1986", "2021"], "values": [0, 100, 100]}}, "type": "Feature"}
# {"geometry": {"coordinates": [-113.747, 53.6451], "type": "Point"}, "properties": {"timeseries": {"dates": ["1986", "1986", "2021"], "values": [0, 100, 100]}}, "type": "Feature"}
# {"geometry": {"coordinates": [108.766, 22.991], "type": "Point"}, "properties": {"timeseries": {"dates": ["1986", "1986", "2021"], "values": [0, 100, 100]}}, "type": "Feature"}
# {"geometry": {"coordinates": [84.0726, 25.6339], "type": "Point"}, "properties": {"timeseries": {"dates": ["1986", "1986", "2021"], "values": [0, 100, 100]}}, "type": "Feature"}
# {"geometry": {"coordinates": [128.148, 45.246], "type": "Point"}, "properties": {"timeseries": {"dates": ["1986", "1986", "2021"], "values": [0, 100, 100]}}, "type": "Feature"}
# {"geometry": {"coordinates": [105.593, 21.5735], "type": "Point"}, "properties": {"timeseries": {"dates": ["1986", "1986", "2021"], "values": [0, 100, 100]}}, "type": "Feature"}
# {"geometry": {"coordinates": [140.195, 35.9088], "type": "Point"}, "properties": {"timeseries": {"dates": ["1986", "1986", "2021"], "values": [0, 100, 100]}}, "type": "Feature"}
# {"geometry": {"coordinates": [-88.2263, 42.894], "type": "Point"}, "properties": {"timeseries": {"dates": ["1986", "1986", "2021"], "values": [0, 100, 100]}}, "type": "Feature"}
# {"geometry": {"coordinates": [80.187, 17.4331], "type": "Point"}, "properties": {"timeseries": {"dates": ["1986", "1986", "2021"], "values": [0, 100, 100]}}, "type": "Feature"}
# {"geometry": {"coordinates": [-54.7281, -33.7104], "type": "Point"}, "properties": {"timeseries": {"dates": ["1986", "1986", "2021"], "values": [0, 100, 100]}}, "type": "Feature"}
# {"geometry": {"coordinates": [-81.5473, 34.3153], "type": "Point"}, "properties": {"timeseries": {"dates": ["1986", "1986", "2021"], "values": [0, 100, 100]}}, "type": "Feature"}
# {"geometry": {"coordinates": [-25.5053, 37.8118], "type": "Point"}, "properties": {"timeseries": {"dates": ["1986", "1986", "2021"], "values": [0, 100, 100]}}, "type": "Feature"}
# {"geometry": {"coordinates": [-102.223, 31.9611], "type": "Point"}, "properties": {"timeseries": {"dates": ["1986", "1986", "2021"], "values": [0, 100, 100]}}, "type": "Feature"}
# {"geometry": {"coordinates": [-99.8429, 25.6963], "type": "Point"}, "properties": {"timeseries": {"dates": ["1986", "1986", "2021"], "values": [0, 100, 100]}}, "type": "Feature"}
# {"geometry": {"coordinates": [-84.4959, 43.1135], "type": "Point"}, "properties": {"timeseries": {"dates": ["1986", "1986", "2021"], "values": [0, 100, 100]}}, "type": "Feature"}
# {"geometry": {"coordinates": [-107.522, 48.0263], "type": "Point"}, "properties": {"timeseries": {"dates": ["1986", "1986", "2021"], "values": [0, 100, 100]}}, "type": "Feature"}
# {"geometry": {"coordinates": [89.4296, 23.6547], "type": "Point"}, "properties": {"timeseries": {"dates": ["1986", "1986", "2021"], "values": [0, 100, 100]}}, "type": "Feature"}
# {"geometry": {"coordinates": [-90.6864, 38.8855], "type": "Point"}, "properties": {"timeseries": {"dates": ["1986", "1986", "2021"], "values": [0, 100, 100]}}, "type": "Feature"}
# {"geometry": {"coordinates": [10.2467, 36.1903], "type": "Point"}, "properties": {"timeseries": {"dates": ["1986", "1986", "2021"], "values": [0, 100, 100]}}, "type": "Feature"}
# {"geometry": {"coordinates": [120.882, 14.6553], "type": "Point"}, "properties": {"timeseries": {"dates": ["1986", "1986", "2021"], "values": [0, 100, 100]}}, "type": "Feature"}
# {"geometry": {"coordinates": [-149.464, 61.7914], "type": "Point"}, "properties": {"timeseries": {"dates": ["1986", "1986", "2021"], "values": [0, 100, 100]}}, "type": "Feature"}
# {"geometry": {"coordinates": [-72.9026, 18.7575], "type": "Point"}, "properties": {"timeseries": {"dates": ["1986", "1986", "2021"], "values": [0, 100, 100]}}, "type": "Feature"}
# {"geometry": {"coordinates": [106.005, -3.70717], "type": "Point"}, "properties": {"timeseries": {"dates": ["1986", "1986", "2021"], "values": [0, 100, 100]}}, "type": "Feature"}
# {"geometry": {"coordinates": [-122.012, 47.6776], "type": "Point"}, "properties": {"timeseries": {"dates": ["1986", "1986", "2021"], "values": [0, 100, 100]}}, "type": "Feature"}
# {"geometry": {"coordinates": [50.5509, 29.8651], "type": "Point"}, "properties": {"timeseries": {"dates": ["1986", "1986", "2021"], "values": [0, 100, 100]}}, "type": "Feature"}
# {"geometry": {"coordinates": [108.708, 13.9153], "type": "Point"}, "properties": {"timeseries": {"dates": ["1986", "1986", "2021"], "values": [0, 100, 100]}}, "type": "Feature"}
# {"geometry": {"coordinates": [-44.4508, -21.7074], "type": "Point"}, "properties": {"timeseries": {"dates": ["1986", "1986", "2021"], "values": [0, 100, 100]}}, "type": "Feature"}
# {"geometry": {"coordinates": [-60.2051, -24.152], "type": "Point"}, "properties": {"timeseries": {"dates": ["1987", "1987", "2021"], "values": [0, 100, 100]}}, "type": "Feature"}
# {"geometry": {"coordinates": [47.4609, -19.6111], "type": "Point"}, "properties": {"timeseries": {"dates": ["1987", "1987", "2021"], "values": [0, 100, 100]}}, "type": "Feature"}
# {"geometry": {"coordinates": [-46.6809, -23.5772], "type": "Point"}, "properties": {"timeseries": {"dates": ["1987", "1987", "2021"], "values": [0, 100, 100]}}, "type": "Feature"}
# {"geometry": {"coordinates": [-64.817, -16.7537], "type": "Point"}, "properties": {"timeseries": {"dates": ["1987", "1987", "2021"], "values": [0, 100, 100]}}, "type": "Feature"}
# {"geometry": {"coordinates": [-74.0575, -12.3047], "type": "Point"}, "properties": {"timeseries": {"dates": ["1987", "1987", "2021"], "values": [0, 100, 100]}}, "type": "Feature"}
# {"geometry": {"coordinates": [41.8577, 43.1418], "type": "Point"}, "properties": {"timeseries": {"dates": ["1987", "1987", "2021"], "values": [0, 100, 100]}}, "type": "Feature"}
# {"geometry": {"coordinates": [111.925, -7.33531], "type": "Point"}, "properties": {"timeseries": {"dates": ["1987", "1987", "2021"], "values": [0, 100, 100]}}, "type": "Feature"}
# {"geometry": {"coordinates": [-77.4907, -0.131721], "type": "Point"}, "properties": {"timeseries": {"dates": ["1987", "1987", "2021"], "values": [0, 100, 100]}}, "type": "Feature"}
# {"geometry": {"coordinates": [-76.7345, -11.8797], "type": "Point"}, "properties": {"timeseries": {"dates": ["1987", "1987", "2021"], "values": [0, 100, 100]}}, "type": "Feature"}
# {"geometry": {"coordinates": [61.4219, 32.5541], "type": "Point"}, "properties": {"timeseries": {"dates": ["1987", "1987", "2021"], "values": [0, 100, 100]}}, "type": "Feature"}
# {"geometry": {"coordinates": [-69.4556, 44.7173], "type": "Point"}, "properties": {"timeseries": {"dates": ["1987", "1987", "2021"], "values": [0, 100, 100]}}, "type": "Feature"}
# {"geometry": {"coordinates": [-79.4853, -2.54852], "type": "Point"}, "properties": {"timeseries": {"dates": ["1987", "1987", "2021"], "values": [0, 100, 100]}}, "type": "Feature"}
# {"geometry": {"coordinates": [19.6312, 44.584], "type": "Point"}, "properties": {"timeseries": {"dates": ["1987", "1987", "2021"], "values": [0, 100, 100]}}, "type": "Feature"}
# {"geometry": {"coordinates": [153.222, -28.4297], "type": "Point"}, "properties": {"timeseries": {"dates": ["1987", "1987", "2021"], "values": [0, 100, 100]}}, "type": "Feature"}
# {"geometry": {"coordinates": [20.6162, 49.6687], "type": "Point"}, "properties": {"timeseries": {"dates": ["1987", "1987", "2021"], "values": [0, 100, 100]}}, "type": "Feature"}
# {"geometry": {"coordinates": [112.803, 23.021], "type": "Point"}, "properties": {"timeseries": {"dates": ["1987", "1987", "2021"], "values": [0, 100, 100]}}, "type": "Feature"}
# {"geometry": {"coordinates": [-95.2617, 40.5924], "type": "Point"}, "properties": {"timeseries": {"dates": ["1987", "1987", "2021"], "values": [0, 100, 100]}}, "type": "Feature"}
# {"geometry": {"coordinates": [-71.0321, 18.5812], "type": "Point"}, "properties": {"timeseries": {"dates": ["1987", "1987", "2021"], "values": [0, 100, 100]}}, "type": "Feature"}
# {"geometry": {"coordinates": [-97.1003, 28.9938], "type": "Point"}, "properties": {"timeseries": {"dates": ["1987", "1987", "2021"], "values": [0, 100, 100]}}, "type": "Feature"}
# {"geometry": {"coordinates": [103.832, 31.0143], "type": "Point"}, "properties": {"timeseries": {"dates": ["1987", "1987", "2021"], "values": [0, 100, 100]}}, "type": "Feature"}
# {"geometry": {"coordinates": [-82.6341, 40.5807], "type": "Point"}, "properties": {"timeseries": {"dates": ["1987", "1987", "2021"], "values": [0, 100, 100]}}, "type": "Feature"}
# {"geometry": {"coordinates": [115.405, 31.4619], "type": "Point"}, "properties": {"timeseries": {"dates": ["1987", "1987", "2021"], "values": [0, 100, 100]}}, "type": "Feature"}
# {"geometry": {"coordinates": [-75.5718, 3.22933], "type": "Point"}, "properties": {"timeseries": {"dates": ["1987", "1987", "2021"], "values": [0, 100, 100]}}, "type": "Feature"}
# {"geometry": {"coordinates": [-71.1067, -33.8689], "type": "Point"}, "properties": {"timeseries": {"dates": ["1987", "1987", "2021"], "values": [0, 100, 100]}}, "type": "Feature"}
# {"geometry": {"coordinates": [9.9383, 45.7794], "type": "Point"}, "properties": {"timeseries": {"dates": ["1987", "1987", "2021"], "values": [0, 100, 100]}}, "type": "Feature"}
# {"geometry": {"coordinates": [-98.7832, 29.9247], "type": "Point"}, "properties": {"timeseries": {"dates": ["1987", "1987", "2021"], "values": [0, 100, 100]}}, "type": "Feature"}
# {"geometry": {"coordinates": [84.3995, 42.1547], "type": "Point"}, "properties": {"timeseries": {"dates": ["1987", "1987", "2021"], "values": [0, 100, 100]}}, "type": "Feature"}
# {"geometry": {"coordinates": [126.932, 36.4164], "type": "Point"}, "properties": {"timeseries": {"dates": ["1987", "1987", "2021"], "values": [0, 100, 100]}}, "type": "Feature"}
# {"geometry": {"coordinates": [51.6599, 35.2053], "type": "Point"}, "properties": {"timeseries": {"dates": ["1987", "1987", "2021"], "values": [0, 100, 100]}}, "type": "Feature"}
# {"geometry": {"coordinates": [91.8011, 24.7767], "type": "Point"}, "properties": {"timeseries": {"dates": ["1987", "1987", "2021"], "values": [0, 100, 100]}}, "type": "Feature"}
# {"geometry": {"coordinates": [117.689, 36.3332], "type": "Point"}, "properties": {"timeseries": {"dates": ["1987", "1987", "2021"], "values": [0, 100, 100]}}, "type": "Feature"}
# {"geometry": {"coordinates": [-66.4167, 10.1321], "type": "Point"}, "properties": {"timeseries": {"dates": ["1987", "1987", "2021"], "values": [0, 100, 100]}}, "type": "Feature"}
# {"geometry": {"coordinates": [124.655, 46.7269], "type": "Point"}, "properties": {"timeseries": {"dates": ["1987", "1987", "2021"], "values": [0, 100, 100]}}, "type": "Feature"}
# {"geometry": {"coordinates": [-75.9401, 40.4228], "type": "Point"}, "properties": {"timeseries": {"dates": ["1987", "1987", "2021"], "values": [0, 100, 100]}}, "type": "Feature"}
# {"geometry": {"coordinates": [30.7003, -29.0897], "type": "Point"}, "properties": {"timeseries": {"dates": ["1987", "1987", "2021"], "values": [0, 100, 100]}}, "type": "Feature"}
# {"geometry": {"coordinates": [-99.122, 19.4762], "type": "Point"}, "properties": {"timeseries": {"dates": ["1987", "1987", "2021"], "values": [0, 100, 100]}}, "type": "Feature"}
# {"geometry": {"coordinates": [-90.7707, 16.658], "type": "Point"}, "properties": {"timeseries": {"dates": ["1987", "1987", "2021"], "values": [0, 100, 100]}}, "type": "Feature"}
# {"geometry": {"coordinates": [2.42823, 42.306], "type": "Point"}, "properties": {"timeseries": {"dates": ["1987", "1987", "2021"], "values": [0, 100, 100]}}, "type": "Feature"}
# {"geometry": {"coordinates": [133.687, 34.973], "type": "Point"}, "properties": {"timeseries": {"dates": ["1987", "1987", "2021"], "values": [0, 100, 100]}}, "type": "Feature"}
# {"geometry": {"coordinates": [33.9157, 28.4698], "type": "Point"}, "properties": {"timeseries": {"dates": ["1987", "1987", "2021"], "values": [0, 100, 100]}}, "type": "Feature"}
# {"geometry": {"coordinates": [121.527, 25.0202], "type": "Point"}, "properties": {"timeseries": {"dates": ["1987", "1987", "2021"], "values": [0, 100, 100]}}, "type": "Feature"}
# {"geometry": {"coordinates": [-76.9826, 18.0492], "type": "Point"}, "properties": {"timeseries": {"dates": ["1987", "1987", "2021"], "values": [0, 100, 100]}}, "type": "Feature"}
# {"geometry": {"coordinates": [-0.936047, 38.6938], "type": "Point"}, "properties": {"timeseries": {"dates": ["1987", "1987", "2021"], "values": [0, 100, 100]}}, "type": "Feature"}
# {"geometry": {"coordinates": [108.372, 13.9903], "type": "Point"}, "properties": {"timeseries": {"dates": ["1987", "1987", "2021"], "values": [0, 100, 100]}}, "type": "Feature"}
# {"geometry": {"coordinates": [-90.0017, 35.3657], "type": "Point"}, "properties": {"timeseries": {"dates": ["1987", "1987", "2021"], "values": [0, 100, 100]}}, "type": "Feature"}
# {"geometry": {"coordinates": [-157.782, 21.3825], "type": "Point"}, "properties": {"timeseries": {"dates": ["1988", "1988", "2021"], "values": [0, 100, 100]}}, "type": "Feature"}
# {"geometry": {"coordinates": [-82.9868, 9.60268], "type": "Point"}, "properties": {"timeseries": {"dates": ["1988", "1988", "2021"], "values": [0, 100, 100]}}, "type": "Feature"}
# {"geometry": {"coordinates": [-70.4315, 19.321], "type": "Point"}, "properties": {"timeseries": {"dates": ["1988", "1988", "2021"], "values": [0, 100, 100]}}, "type": "Feature"}
# {"geometry": {"coordinates": [-90.22, 30.6473], "type": "Point"}, "properties": {"timeseries": {"dates": ["1988", "1988", "2021"], "values": [0, 100, 100]}}, "type": "Feature"}
# {"geometry": {"coordinates": [-43.2761, -22.4939], "type": "Point"}, "properties": {"timeseries": {"dates": ["1988", "1988", "2021"], "values": [0, 100, 100]}}, "type": "Feature"}
# {"geometry": {"coordinates": [110.614, -7.76758], "type": "Point"}, "properties": {"timeseries": {"dates": ["1988", "1988", "2021"], "values": [0, 100, 100]}}, "type": "Feature"}
# {"geometry": {"coordinates": [24.3587, -28.8429], "type": "Point"}, "properties": {"timeseries": {"dates": ["1988", "1988", "2021"], "values": [0, 100, 100]}}, "type": "Feature"}
# {"geometry": {"coordinates": [-72.4803, -12.823], "type": "Point"}, "properties": {"timeseries": {"dates": ["1988", "1988", "2021"], "values": [0, 100, 100]}}, "type": "Feature"}
# {"geometry": {"coordinates": [26.9543, -22.1508], "type": "Point"}, "properties": {"timeseries": {"dates": ["1988", "1988", "2021"], "values": [0, 100, 100]}}, "type": "Feature"}
# {"geometry": {"coordinates": [-59.0423, -34.6391], "type": "Point"}, "properties": {"timeseries": {"dates": ["1988", "1988", "2021"], "values": [0, 100, 100]}}, "type": "Feature"}
# {"geometry": {"coordinates": [10.0852, 49.8867], "type": "Point"}, "properties": {"timeseries": {"dates": ["1988", "1988", "2021"], "values": [0, 100, 100]}}, "type": "Feature"}
# {"geometry": {"coordinates": [119.782, -20.5349], "type": "Point"}, "properties": {"timeseries": {"dates": ["1988", "1988", "2021"], "values": [0, 100, 100]}}, "type": "Feature"}
# {"geometry": {"coordinates": [42.6368, 37.441], "type": "Point"}, "properties": {"timeseries": {"dates": ["1988", "1988", "2021"], "values": [0, 100, 100]}}, "type": "Feature"}
# {"geometry": {"coordinates": [15.6402, 49.345], "type": "Point"}, "properties": {"timeseries": {"dates": ["1988", "1988", "2021"], "values": [0, 100, 100]}}, "type": "Feature"}
# {"geometry": {"coordinates": [36.3806, -0.996029], "type": "Point"}, "properties": {"timeseries": {"dates": ["1988", "1988", "2021"], "values": [0, 100, 100]}}, "type": "Feature"}
# {"geometry": {"coordinates": [130.88, 32.5616], "type": "Point"}, "properties": {"timeseries": {"dates": ["1988", "1988", "2021"], "values": [0, 100, 100]}}, "type": "Feature"}
# {"geometry": {"coordinates": [30.4125, -0.829098], "type": "Point"}, "properties": {"timeseries": {"dates": ["1988", "1988", "2021"], "values": [0, 100, 100]}}, "type": "Feature"}
# {"geometry": {"coordinates": [118.907, 26.9901], "type": "Point"}, "properties": {"timeseries": {"dates": ["1988", "1988", "2021"], "values": [0, 100, 100]}}, "type": "Feature"}
# {"geometry": {"coordinates": [92.0622, 26.4813], "type": "Point"}, "properties": {"timeseries": {"dates": ["1988", "1988", "2021"], "values": [0, 100, 100]}}, "type": "Feature"}
# {"geometry": {"coordinates": [113.629, 25.0845], "type": "Point"}, "properties": {"timeseries": {"dates": ["1988", "1988", "2021"], "values": [0, 100, 100]}}, "type": "Feature"}
# {"geometry": {"coordinates": [-79.1496, 21.6272], "type": "Point"}, "properties": {"timeseries": {"dates": ["1988", "1988", "2021"], "values": [0, 100, 100]}}, "type": "Feature"}
# {"geometry": {"coordinates": [80.4188, 6.5639], "type": "Point"}, "properties": {"timeseries": {"dates": ["1988", "1988", "2021"], "values": [0, 100, 100]}}, "type": "Feature"}
# {"geometry": {"coordinates": [121.197, 14.6581], "type": "Point"}, "properties": {"timeseries": {"dates": ["1988", "1988", "2021"], "values": [0, 100, 100]}}, "type": "Feature"}
# {"geometry": {"coordinates": [69.4328, 36.3288], "type": "Point"}, "properties": {"timeseries": {"dates": ["1988", "1988", "2021"], "values": [0, 100, 100]}}, "type": "Feature"}
# {"geometry": {"coordinates": [108.938, 28.7125], "type": "Point"}, "properties": {"timeseries": {"dates": ["1988", "1988", "2021"], "values": [0, 100, 100]}}, "type": "Feature"}
# {"geometry": {"coordinates": [32.9515, 40.0061], "type": "Point"}, "properties": {"timeseries": {"dates": ["1988", "1988", "2021"], "values": [0, 100, 100]}}, "type": "Feature"}
# {"geometry": {"coordinates": [89.2694, 22.9348], "type": "Point"}, "properties": {"timeseries": {"dates": ["1988", "1988", "2021"], "values": [0, 100, 100]}}, "type": "Feature"}
# {"geometry": {"coordinates": [117.978, 28.2371], "type": "Point"}, "properties": {"timeseries": {"dates": ["1988", "1988", "2021"], "values": [0, 100, 100]}}, "type": "Feature"}
# {"geometry": {"coordinates": [92.926, 26.988], "type": "Point"}, "properties": {"timeseries": {"dates": ["1988", "1988", "2021"], "values": [0, 100, 100]}}, "type": "Feature"}
# {"geometry": {"coordinates": [24.7132, 51.4768], "type": "Point"}, "properties": {"timeseries": {"dates": ["1988", "1988", "2021"], "values": [0, 100, 100]}}, "type": "Feature"}
# {"geometry": {"coordinates": [104.148, 29.5434], "type": "Point"}, "properties": {"timeseries": {"dates": ["1988", "1988", "2021"], "values": [0, 100, 100]}}, "type": "Feature"}
# {"geometry": {"coordinates": [90.7053, 24.0121], "type": "Point"}, "properties": {"timeseries": {"dates": ["1988", "1988", "2021"], "values": [0, 100, 100]}}, "type": "Feature"}
# {"geometry": {"coordinates": [-58.1136, -26.2024], "type": "Point"}, "properties": {"timeseries": {"dates": ["1988", "1988", "2021"], "values": [0, 100, 100]}}, "type": "Feature"}
# {"geometry": {"coordinates": [3.45225, 6.58518], "type": "Point"}, "properties": {"timeseries": {"dates": ["1988", "1988", "2021"], "values": [0, 100, 100]}}, "type": "Feature"}
# {"geometry": {"coordinates": [80.7246, 28.886], "type": "Point"}, "properties": {"timeseries": {"dates": ["1988", "1988", "2021"], "values": [0, 100, 100]}}, "type": "Feature"}
# {"geometry": {"coordinates": [-114.841, 55.4087], "type": "Point"}, "properties": {"timeseries": {"dates": ["1988", "1988", "2021"], "values": [0, 100, 100]}}, "type": "Feature"}
# {"geometry": {"coordinates": [39.8909, 45.3603], "type": "Point"}, "properties": {"timeseries": {"dates": ["1988", "1988", "2021"], "values": [0, 100, 100]}}, "type": "Feature"}
# {"geometry": {"coordinates": [103.879, 34.7195], "type": "Point"}, "properties": {"timeseries": {"dates": ["1988", "1988", "2021"], "values": [0, 100, 100]}}, "type": "Feature"}
# {"geometry": {"coordinates": [127.777, 37.8837], "type": "Point"}, "properties": {"timeseries": {"dates": ["1988", "1988", "2021"], "values": [0, 100, 100]}}, "type": "Feature"}
# {"geometry": {"coordinates": [-99.3069, 30.0496], "type": "Point"}, "properties": {"timeseries": {"dates": ["1988", "1988", "2021"], "values": [0, 100, 100]}}, "type": "Feature"}
# {"geometry": {"coordinates": [133.882, 35.3673], "type": "Point"}, "properties": {"timeseries": {"dates": ["1988", "1988", "2021"], "values": [0, 100, 100]}}, "type": "Feature"}
# {"geometry": {"coordinates": [71.1117, 22.0189], "type": "Point"}, "properties": {"timeseries": {"dates": ["1988", "1988", "2021"], "values": [0, 100, 100]}}, "type": "Feature"}
# {"geometry": {"coordinates": [-35.9246, -8.84383], "type": "Point"}, "properties": {"timeseries": {"dates": ["1988", "1988", "2021"], "values": [0, 100, 100]}}, "type": "Feature"}
# {"geometry": {"coordinates": [72.1319, 31.8882], "type": "Point"}, "properties": {"timeseries": {"dates": ["1988", "1988", "2021"], "values": [0, 100, 100]}}, "type": "Feature"}
# {"geometry": {"coordinates": [128.562, 36.9815], "type": "Point"}, "properties": {"timeseries": {"dates": ["1988", "1988", "2021"], "values": [0, 100, 100]}}, "type": "Feature"}
# {"geometry": {"coordinates": [-2.07723, 43.107], "type": "Point"}, "properties": {"timeseries": {"dates": ["1988", "1988", "2021"], "values": [0, 100, 100]}}, "type": "Feature"}
# {"geometry": {"coordinates": [132.171, 34.6244], "type": "Point"}, "properties": {"timeseries": {"dates": ["1988", "1988", "2021"], "values": [0, 100, 100]}}, "type": "Feature"}
# {"geometry": {"coordinates": [123.762, 47.528], "type": "Point"}, "properties": {"timeseries": {"dates": ["1988", "1988", "2021"], "values": [0, 100, 100]}}, "type": "Feature"}
# {"geometry": {"coordinates": [107.648, 36.2462], "type": "Point"}, "properties": {"timeseries": {"dates": ["1988", "1988", "2021"], "values": [0, 100, 100]}}, "type": "Feature"}
# {"geometry": {"coordinates": [175.503, -36.63], "type": "Point"}, "properties": {"timeseries": {"dates": ["1988", "1988", "2021"], "values": [0, 100, 100]}}, "type": "Feature"}
# {"geometry": {"coordinates": [120.759, 29.0944], "type": "Point"}, "properties": {"timeseries": {"dates": ["1988", "1988", "2021"], "values": [0, 100, 100]}}, "type": "Feature"}
# {"geometry": {"coordinates": [-68.4309, 10.9636], "type": "Point"}, "properties": {"timeseries": {"dates": ["1988", "1988", "2021"], "values": [0, 100, 100]}}, "type": "Feature"}
# {"geometry": {"coordinates": [80.713, 18.4311], "type": "Point"}, "properties": {"timeseries": {"dates": ["1988", "1988", "2021"], "values": [0, 100, 100]}}, "type": "Feature"}
# {"geometry": {"coordinates": [91.8093, 59.7121], "type": "Point"}, "properties": {"timeseries": {"dates": ["1988", "1988", "2021"], "values": [0, 100, 100]}}, "type": "Feature"}
# {"geometry": {"coordinates": [112.511, 37.9044], "type": "Point"}, "properties": {"timeseries": {"dates": ["1988", "1988", "2021"], "values": [0, 100, 100]}}, "type": "Feature"}
# {"geometry": {"coordinates": [34.1974, 15.0782], "type": "Point"}, "properties": {"timeseries": {"dates": ["1988", "1988", "2021"], "values": [0, 100, 100]}}, "type": "Feature"}
# {"geometry": {"coordinates": [120.998, 30.1638], "type": "Point"}, "properties": {"timeseries": {"dates": ["1988", "1988", "2021"], "values": [0, 100, 100]}}, "type": "Feature"}
# {"geometry": {"coordinates": [124.933, 50.3978], "type": "Point"}, "properties": {"timeseries": {"dates": ["1988", "1988", "2021"], "values": [0, 100, 100]}}, "type": "Feature"}
# {"geometry": {"coordinates": [120.448, 23.3725], "type": "Point"}, "properties": {"timeseries": {"dates": ["1988", "1988", "2021"], "values": [0, 100, 100]}}, "type": "Feature"}
# {"geometry": {"coordinates": [-96.0178, 18.4042], "type": "Point"}, "properties": {"timeseries": {"dates": ["1988", "1988", "2021"], "values": [0, 100, 100]}}, "type": "Feature"}
# {"geometry": {"coordinates": [-83.9236, 14.4458], "type": "Point"}, "properties": {"timeseries": {"dates": ["1988", "1988", "2021"], "values": [0, 100, 100]}}, "type": "Feature"}
# {"geometry": {"coordinates": [110.234, 35.9866], "type": "Point"}, "properties": {"timeseries": {"dates": ["1988", "1988", "2021"], "values": [0, 100, 100]}}, "type": "Feature"}
# {"geometry": {"coordinates": [-63.565, 8.82924], "type": "Point"}, "properties": {"timeseries": {"dates": ["1988", "1988", "2021"], "values": [0, 100, 100]}}, "type": "Feature"}
# {"geometry": {"coordinates": [9.09773, 11.8707], "type": "Point"}, "properties": {"timeseries": {"dates": ["1988", "1988", "2021"], "values": [0, 100, 100]}}, "type": "Feature"}
# {"geometry": {"coordinates": [114.489, 34.293], "type": "Point"}, "properties": {"timeseries": {"dates": ["1988", "1988", "2021"], "values": [0, 100, 100]}}, "type": "Feature"}
# {"geometry": {"coordinates": [90.3467, 23.8201], "type": "Point"}, "properties": {"timeseries": {"dates": ["1988", "1988", "2021"], "values": [0, 100, 100]}}, "type": "Feature"}
# {"geometry": {"coordinates": [86.5429, 26.5037], "type": "Point"}, "properties": {"timeseries": {"dates": ["1988", "1988", "2021"], "values": [0, 100, 100]}}, "type": "Feature"}
# {"geometry": {"coordinates": [32.9238, 2.6893], "type": "Point"}, "properties": {"timeseries": {"dates": ["1988", "1988", "2021"], "values": [0, 100, 100]}}, "type": "Feature"}
# {"geometry": {"coordinates": [7.08584, 4.54794], "type": "Point"}, "properties": {"timeseries": {"dates": ["1988", "1988", "2021"], "values": [0, 100, 100]}}, "type": "Feature"}
# {"geometry": {"coordinates": [-4.19711, 11.5463], "type": "Point"}, "properties": {"timeseries": {"dates": ["1988", "1988", "2021"], "values": [0, 100, 100]}}, "type": "Feature"}
# {"geometry": {"coordinates": [-104.497, 21.5773], "type": "Point"}, "properties": {"timeseries": {"dates": ["1988", "1988", "2021"], "values": [0, 100, 100]}}, "type": "Feature"}
# {"geometry": {"coordinates": [117.954, 37.4146], "type": "Point"}, "properties": {"timeseries": {"dates": ["1988", "1988", "2021"], "values": [0, 100, 100]}}, "type": "Feature"}
# {"geometry": {"coordinates": [68.0427, 25.6834], "type": "Point"}, "properties": {"timeseries": {"dates": ["1988", "1988", "2021"], "values": [0, 100, 100]}}, "type": "Feature"}
# {"geometry": {"coordinates": [7.85685, 15.5663], "type": "Point"}, "properties": {"timeseries": {"dates": ["1988", "1988", "2021"], "values": [0, 100, 100]}}, "type": "Feature"}
# {"geometry": {"coordinates": [20.825, 12.2248], "type": "Point"}, "properties": {"timeseries": {"dates": ["1988", "1988", "2021"], "values": [0, 100, 100]}}, "type": "Feature"}
# {"geometry": {"coordinates": [-88.8546, 13.6283], "type": "Point"}, "properties": {"timeseries": {"dates": ["1988", "1988", "2021"], "values": [0, 100, 100]}}, "type": "Feature"}
# {"geometry": {"coordinates": [110.803, 23.5246], "type": "Point"}, "properties": {"timeseries": {"dates": ["1988", "1988", "2021"], "values": [0, 100, 100]}}, "type": "Feature"}
# {"geometry": {"coordinates": [52.2925, 35.55], "type": "Point"}, "properties": {"timeseries": {"dates": ["1988", "1988", "2021"], "values": [0, 100, 100]}}, "type": "Feature"}
# {"geometry": {"coordinates": [-75.0642, 7.46115], "type": "Point"}, "properties": {"timeseries": {"dates": ["1988", "1988", "2021"], "values": [0, 100, 100]}}, "type": "Feature"}
# {"geometry": {"coordinates": [-17.0028, 14.7289], "type": "Point"}, "properties": {"timeseries": {"dates": ["1988", "1988", "2021"], "values": [0, 100, 100]}}, "type": "Feature"}
# {"geometry": {"coordinates": [2.32843, 13.4802], "type": "Point"}, "properties": {"timeseries": {"dates": ["1988", "1988", "2021"], "values": [0, 100, 100]}}, "type": "Feature"}
# {"geometry": {"coordinates": [-93.4599, 15.749], "type": "Point"}, "properties": {"timeseries": {"dates": ["1988", "1988", "2021"], "values": [0, 100, 100]}}, "type": "Feature"}
# {"geometry": {"coordinates": [-97.5615, 20.7098], "type": "Point"}, "properties": {"timeseries": {"dates": ["1988", "1988", "2021"], "values": [0, 100, 100]}}, "type": "Feature"}
# {"geometry": {"coordinates": [110.35, 52.3035], "type": "Point"}, "properties": {"timeseries": {"dates": ["1988", "1988", "2021"], "values": [0, 100, 100]}}, "type": "Feature"}
# {"geometry": {"coordinates": [112.441, 29.1543], "type": "Point"}, "properties": {"timeseries": {"dates": ["1988", "1988", "2021"], "values": [0, 100, 100]}}, "type": "Feature"}
# {"geometry": {"coordinates": [-82.4462, 27.7659], "type": "Point"}, "properties": {"timeseries": {"dates": ["1988", "1988", "2021"], "values": [0, 100, 100]}}, "type": "Feature"}
# {"geometry": {"coordinates": [-88.6221, 20.9216], "type": "Point"}, "properties": {"timeseries": {"dates": ["1988", "1988", "2021"], "values": [0, 100, 100]}}, "type": "Feature"}
# {"geometry": {"coordinates": [2.40705, 9.50559], "type": "Point"}, "properties": {"timeseries": {"dates": ["1988", "1988", "2021"], "values": [0, 100, 100]}}, "type": "Feature"}
# {"geometry": {"coordinates": [82.4632, 28.7764], "type": "Point"}, "properties": {"timeseries": {"dates": ["1988", "1988", "2021"], "values": [0, 100, 100]}}, "type": "Feature"}
# {"geometry": {"coordinates": [101.507, 16.0791], "type": "Point"}, "properties": {"timeseries": {"dates": ["1988", "1988", "2021"], "values": [0, 100, 100]}}, "type": "Feature"}
# {"geometry": {"coordinates": [118.345, 25.7425], "type": "Point"}, "properties": {"timeseries": {"dates": ["1988", "1988", "2021"], "values": [0, 100, 100]}}, "type": "Feature"}
# {"geometry": {"coordinates": [75.0459, 30.9339], "type": "Point"}, "properties": {"timeseries": {"dates": ["1988", "1988", "2021"], "values": [0, 100, 100]}}, "type": "Feature"}
# {"geometry": {"coordinates": [121.521, 24.0029], "type": "Point"}, "properties": {"timeseries": {"dates": ["1988", "1988", "2021"], "values": [0, 100, 100]}}, "type": "Feature"}
# {"geometry": {"coordinates": [72.8962, 19.1131], "type": "Point"}, "properties": {"timeseries": {"dates": ["1988", "1988", "2021"], "values": [0, 100, 100]}}, "type": "Feature"}
# {"geometry": {"coordinates": [4.3611, 43.8055], "type": "Point"}, "properties": {"timeseries": {"dates": ["1988", "1988", "2021"], "values": [0, 100, 100]}}, "type": "Feature"}
# {"geometry": {"coordinates": [7.10119, 6.37902], "type": "Point"}, "properties": {"timeseries": {"dates": ["1988", "1988", "2021"], "values": [0, 100, 100]}}, "type": "Feature"}
# {"geometry": {"coordinates": [-1.18135, 9.63061], "type": "Point"}, "properties": {"timeseries": {"dates": ["1988", "1988", "2021"], "values": [0, 100, 100]}}, "type": "Feature"}
# {"geometry": {"coordinates": [-90.5272, 16.024], "type": "Point"}, "properties": {"timeseries": {"dates": ["1988", "1988", "2021"], "values": [0, 100, 100]}}, "type": "Feature"}
# {"geometry": {"coordinates": [106.498, 17.6857], "type": "Point"}, "properties": {"timeseries": {"dates": ["1988", "1988", "2021"], "values": [0, 100, 100]}}, "type": "Feature"}
# {"geometry": {"coordinates": [-83.8687, 12.4945], "type": "Point"}, "properties": {"timeseries": {"dates": ["1988", "1988", "2021"], "values": [0, 100, 100]}}, "type": "Feature"}
# {"geometry": {"coordinates": [125.763, 8.56968], "type": "Point"}, "properties": {"timeseries": {"dates": ["1988", "1988", "2021"], "values": [0, 100, 100]}}, "type": "Feature"}
# {"geometry": {"coordinates": [6.31012, 4.97124], "type": "Point"}, "properties": {"timeseries": {"dates": ["1988", "1988", "2021"], "values": [0, 100, 100]}}, "type": "Feature"}
# {"geometry": {"coordinates": [110.429, 19.6114], "type": "Point"}, "properties": {"timeseries": {"dates": ["1988", "1988", "2021"], "values": [0, 100, 100]}}, "type": "Feature"}
# {"geometry": {"coordinates": [121.641, -8.80602], "type": "Point"}, "properties": {"timeseries": {"dates": ["1988", "1988", "2021"], "values": [0, 100, 100]}}, "type": "Feature"}
# {"geometry": {"coordinates": [123.271, 13.6637], "type": "Point"}, "properties": {"timeseries": {"dates": ["1988", "1988", "2021"], "values": [0, 100, 100]}}, "type": "Feature"}
# {"geometry": {"coordinates": [-0.560405, 39.7108], "type": "Point"}, "properties": {"timeseries": {"dates": ["1988", "1988", "2021"], "values": [0, 100, 100]}}, "type": "Feature"}
# {"geometry": {"coordinates": [98.0389, 3.35681], "type": "Point"}, "properties": {"timeseries": {"dates": ["1988", "1988", "2021"], "values": [0, 100, 100]}}, "type": "Feature"}
# {"geometry": {"coordinates": [99.8198, 8.29737], "type": "Point"}, "properties": {"timeseries": {"dates": ["1988", "1988", "2021"], "values": [0, 100, 100]}}, "type": "Feature"}
# ...
# {"geometry": {"coordinates": [-70.7561, -12.066], "type": "Point"}, "properties": {"timeseries": {"dates": ["2021", "2021", "2021"], "values": [0, 100, 100]}}, "type": "Feature"}
# {"geometry": {"coordinates": [-84.3156, 36.833], "type": "Point"}, "properties": {"timeseries": {"dates": ["2021", "2021", "2021"], "values": [0, 100, 100]}}, "type": "Feature"}
# {"geometry": {"coordinates": [150.909, -30.8531], "type": "Point"}, "properties": {"timeseries": {"dates": ["2021", "2021", "2021"], "values": [0, 100, 100]}}, "type": "Feature"}
# {"geometry": {"coordinates": [13.8295, -9.46143], "type": "Point"}, "properties": {"timeseries": {"dates": ["2021", "2021", "2021"], "values": [0, 100, 100]}}, "type": "Feature"}
# {"geometry": {"coordinates": [-50.5036, -27.1322], "type": "Point"}, "properties": {"timeseries": {"dates": ["2021", "2021", "2021"], "values": [0, 100, 100]}}, "type": "Feature"}
# {"geometry": {"coordinates": [-76.4224, 7.30687], "type": "Point"}, "properties": {"timeseries": {"dates": ["2021", "2021", "2021"], "values": [0, 100, 100]}}, "type": "Feature"}
# {"geometry": {"coordinates": [107.137, -6.76914], "type": "Point"}, "properties": {"timeseries": {"dates": ["2021", "2021", "2021"], "values": [0, 100, 100]}}, "type": "Feature"}
# {"geometry": {"coordinates": [-72.3521, 18.9203], "type": "Point"}, "properties": {"timeseries": {"dates": ["2021", "2021", "2021"], "values": [0, 100, 100]}}, "type": "Feature"}
# {"geometry": {"coordinates": [-73.0201, 1.66438], "type": "Point"}, "properties": {"timeseries": {"dates": ["2021", "2021", "2021"], "values": [0, 100, 100]}}, "type": "Feature"}
# {"geometry": {"coordinates": [124.8, -9.33179], "type": "Point"}, "properties": {"timeseries": {"dates": ["2021", "2021", "2021"], "values": [0, 100, 100]}}, "type": "Feature"}
# {"geometry": {"coordinates": [109.513, -7.26584], "type": "Point"}, "properties": {"timeseries": {"dates": ["2021", "2021", "2021"], "values": [0, 100, 100]}}, "type": "Feature"}
# {"geometry": {"coordinates": [-74.4553, -3.02046], "type": "Point"}, "properties": {"timeseries": {"dates": ["2021", "2021", "2021"], "values": [0, 100, 100]}}, "type": "Feature"}
# {"geometry": {"coordinates": [29.8881, -1.58531], "type": "Point"}, "properties": {"timeseries": {"dates": ["2021", "2021", "2021"], "values": [0, 100, 100]}}, "type": "Feature"}
# {"geometry": {"coordinates": [125.485, 7.01944], "type": "Point"}, "properties": {"timeseries": {"dates": ["2021", "2021", "2021"], "values": [0, 100, 100]}}, "type": "Feature"}
# {"geometry": {"coordinates": [-70.6819, 8.99006], "type": "Point"}, "properties": {"timeseries": {"dates": ["2021", "2021", "2021"], "values": [0, 100, 100]}}, "type": "Feature"}
# {"geometry": {"coordinates": [35.4059, -0.422939], "type": "Point"}, "properties": {"timeseries": {"dates": ["2021", "2021", "2021"], "values": [0, 100, 100]}}, "type": "Feature"}
# {"geometry": {"coordinates": [13.78, -9.28778], "type": "Point"}, "properties": {"timeseries": {"dates": ["2021", "2021", "2021"], "values": [0, 100, 100]}}, "type": "Feature"}
# {"geometry": {"coordinates": [-77.7214, 2.28697], "type": "Point"}, "properties": {"timeseries": {"dates": ["2021", "2021", "2021"], "values": [0, 100, 100]}}, "type": "Feature"}
# {"geometry": {"coordinates": [65.9888, 34.2478], "type": "Point"}, "properties": {"timeseries": {"dates": ["2021", "2021", "2021"], "values": [0, 100, 100]}}, "type": "Feature"}
# {"geometry": {"coordinates": [49.5591, 16.3552], "type": "Point"}, "properties": {"timeseries": {"dates": ["2021", "2021", "2021"], "values": [0, 100, 100]}}, "type": "Feature"}
# {"geometry": {"coordinates": [31.6943, -0.272389], "type": "Point"}, "properties": {"timeseries": {"dates": ["2021", "2021", "2021"], "values": [0, 100, 100]}}, "type": "Feature"}
# {"geometry": {"coordinates": [20.8567, -33.8857], "type": "Point"}, "properties": {"timeseries": {"dates": ["2021", "2021", "2021"], "values": [0, 100, 100]}}, "type": "Feature"}
# {"geometry": {"coordinates": [45.2538, 2.54787], "type": "Point"}, "properties": {"timeseries": {"dates": ["2021", "2021", "2021"], "values": [0, 100, 100]}}, "type": "Feature"}
# {"geometry": {"coordinates": [56.5863, 32.3928], "type": "Point"}, "properties": {"timeseries": {"dates": ["2021", "2021", "2021"], "values": [0, 100, 100]}}, "type": "Feature"}
# {"geometry": {"coordinates": [23.331, 47.2608], "type": "Point"}, "properties": {"timeseries": {"dates": ["2021", "2021", "2021"], "values": [0, 100, 100]}}, "type": "Feature"}
# {"geometry": {"coordinates": [37.2616, 7.53523], "type": "Point"}, "properties": {"timeseries": {"dates": ["2021", "2021", "2021"], "values": [0, 100, 100]}}, "type": "Feature"}
# {"geometry": {"coordinates": [135.716, 48.9893], "type": "Point"}, "properties": {"timeseries": {"dates": ["2021", "2021", "2021"], "values": [0, 100, 100]}}, "type": "Feature"}
# {"geometry": {"coordinates": [5.78789, 35.7154], "type": "Point"}, "properties": {"timeseries": {"dates": ["2021", "2021", "2021"], "values": [0, 100, 100]}}, "type": "Feature"}
# {"geometry": {"coordinates": [85.4651, 56.1379], "type": "Point"}, "properties": {"timeseries": {"dates": ["2021", "2021", "2021"], "values": [0, 100, 100]}}, "type": "Feature"}
# {"geometry": {"coordinates": [108.176, -7.0049], "type": "Point"}, "properties": {"timeseries": {"dates": ["2021", "2021", "2021"], "values": [0, 100, 100]}}, "type": "Feature"}
# {"geometry": {"coordinates": [-66.0425, -4.23979], "type": "Point"}, "properties": {"timeseries": {"dates": ["2021", "2021", "2021"], "values": [0, 100, 100]}}, "type": "Feature"}
# {"geometry": {"coordinates": [-93.1366, 31.4521], "type": "Point"}, "properties": {"timeseries": {"dates": ["2021", "2021", "2021"], "values": [0, 100, 100]}}, "type": "Feature"}
# {"geometry": {"coordinates": [85.5114, 21.6184], "type": "Point"}, "properties": {"timeseries": {"dates": ["2021", "2021", "2021"], "values": [0, 100, 100]}}, "type": "Feature"}
# {"geometry": {"coordinates": [73.2139, 18.202], "type": "Point"}, "properties": {"timeseries": {"dates": ["2021", "2021", "2021"], "values": [0, 100, 100]}}, "type": "Feature"}
# {"geometry": {"coordinates": [-62.034, -2.08431], "type": "Point"}, "properties": {"timeseries": {"dates": ["2021", "2021", "2021"], "values": [0, 100, 100]}}, "type": "Feature"}
# {"geometry": {"coordinates": [-72.2778, -37.8809], "type": "Point"}, "properties": {"timeseries": {"dates": ["2021", "2021", "2021"], "values": [0, 100, 100]}}, "type": "Feature"}
# {"geometry": {"coordinates": [124.73, 8.60607], "type": "Point"}, "properties": {"timeseries": {"dates": ["2021", "2021", "2021"], "values": [0, 100, 100]}}, "type": "Feature"}
# {"geometry": {"coordinates": [171.545, -43.1109], "type": "Point"}, "properties": {"timeseries": {"dates": ["2021", "2021", "2021"], "values": [0, 100, 100]}}, "type": "Feature"}
# {"geometry": {"coordinates": [-84.996, 33.4811], "type": "Point"}, "properties": {"timeseries": {"dates": ["2021", "2021", "2021"], "values": [0, 100, 100]}}, "type": "Feature"}
# {"geometry": {"coordinates": [-86.5177, 39.196], "type": "Point"}, "properties": {"timeseries": {"dates": ["2021", "2021", "2021"], "values": [0, 100, 100]}}, "type": "Feature"}
# {"geometry": {"coordinates": [80.6839, 27.6821], "type": "Point"}, "properties": {"timeseries": {"dates": ["2021", "2021", "2021"], "values": [0, 100, 100]}}, "type": "Feature"}
# {"geometry": {"coordinates": [176.499, -39.4563], "type": "Point"}, "properties": {"timeseries": {"dates": ["2021", "2021", "2021"], "values": [0, 100, 100]}}, "type": "Feature"}
# {"geometry": {"coordinates": [36.1977, 45.2459], "type": "Point"}, "properties": {"timeseries": {"dates": ["2021", "2021", "2021"], "values": [0, 100, 100]}}, "type": "Feature"}
# {"geometry": {"coordinates": [-96.8234, 17.2343], "type": "Point"}, "properties": {"timeseries": {"dates": ["2021", "2021", "2021"], "values": [0, 100, 100]}}, "type": "Feature"}
# {"geometry": {"coordinates": [-58.9658, 5.15327], "type": "Point"}, "properties": {"timeseries": {"dates": ["2021", "2021", "2021"], "values": [0, 100, 100]}}, "type": "Feature"}
# {"geometry": {"coordinates": [86.13, 28.2008], "type": "Point"}, "properties": {"timeseries": {"dates": ["2021", "2021", "2021"], "values": [0, 100, 100]}}, "type": "Feature"}
# {"geometry": {"coordinates": [116.193, 27.0073], "type": "Point"}, "properties": {"timeseries": {"dates": ["2021", "2021", "2021"], "values": [0, 100, 100]}}, "type": "Feature"}
# {"geometry": {"coordinates": [84.0021, 28.3125], "type": "Point"}, "properties": {"timeseries": {"dates": ["2021", "2021", "2021"], "values": [0, 100, 100]}}, "type": "Feature"}
# {"geometry": {"coordinates": [94.2212, 27.3659], "type": "Point"}, "properties": {"timeseries": {"dates": ["2021", "2021", "2021"], "values": [0, 100, 100]}}, "type": "Feature"}
# {"geometry": {"coordinates": [127.229, 34.9359], "type": "Point"}, "properties": {"timeseries": {"dates": ["2021", "2021", "2021"], "values": [0, 100, 100]}}, "type": "Feature"}
# {"geometry": {"coordinates": [97.0172, 4.25715], "type": "Point"}, "properties": {"timeseries": {"dates": ["2021", "2021", "2021"], "values": [0, 100, 100]}}, "type": "Feature"}
# {"geometry": {"coordinates": [37.4225, 44.9971], "type": "Point"}, "properties": {"timeseries": {"dates": ["2021", "2021", "2021"], "values": [0, 100, 100]}}, "type": "Feature"}
# {"geometry": {"coordinates": [6.62917, 51.1613], "type": "Point"}, "properties": {"timeseries": {"dates": ["2021", "2021", "2021"], "values": [0, 100, 100]}}, "type": "Feature"}
# {"geometry": {"coordinates": [113.1, 34.0247], "type": "Point"}, "properties": {"timeseries": {"dates": ["2021", "2021", "2021"], "values": [0, 100, 100]}}, "type": "Feature"}
# {"geometry": {"coordinates": [70.9375, 35.0881], "type": "Point"}, "properties": {"timeseries": {"dates": ["2021", "2021", "2021"], "values": [0, 100, 100]}}, "type": "Feature"}
# {"geometry": {"coordinates": [-111.014, 31.2745], "type": "Point"}, "properties": {"timeseries": {"dates": ["2021", "2021", "2021"], "values": [0, 100, 100]}}, "type": "Feature"}
# {"geometry": {"coordinates": [73.1273, 34.1447], "type": "Point"}, "properties": {"timeseries": {"dates": ["2021", "2021", "2021"], "values": [0, 100, 100]}}, "type": "Feature"}
# {"geometry": {"coordinates": [97.5863, 23.1495], "type": "Point"}, "properties": {"timeseries": {"dates": ["2021", "2021", "2021"], "values": [0, 100, 100]}}, "type": "Feature"}
# {"geometry": {"coordinates": [74.7233, 33.3259], "type": "Point"}, "properties": {"timeseries": {"dates": ["2021", "2021", "2021"], "values": [0, 100, 100]}}, "type": "Feature"}
# {"geometry": {"coordinates": [-110.581, 36.419], "type": "Point"}, "properties": {"timeseries": {"dates": ["2021", "2021", "2021"], "values": [0, 100, 100]}}, "type": "Feature"}
# {"geometry": {"coordinates": [-84.1052, 9.80222], "type": "Point"}, "properties": {"timeseries": {"dates": ["2021", "2021", "2021"], "values": [0, 100, 100]}}, "type": "Feature"}
# {"geometry": {"coordinates": [-82.002, 8.78486], "type": "Point"}, "properties": {"timeseries": {"dates": ["2021", "2021", "2021"], "values": [0, 100, 100]}}, "type": "Feature"}
# {"geometry": {"coordinates": [76.0347, 14.5568], "type": "Point"}, "properties": {"timeseries": {"dates": ["2021", "2021", "2021"], "values": [0, 100, 100]}}, "type": "Feature"}
# {"geometry": {"coordinates": [92.1303, 21.875], "type": "Point"}, "properties": {"timeseries": {"dates": ["2021", "2021", "2021"], "values": [0, 100, 100]}}, "type": "Feature"}
# {"geometry": {"coordinates": [9.12827, 12.1102], "type": "Point"}, "properties": {"timeseries": {"dates": ["2021", "2021", "2021"], "values": [0, 100, 100]}}, "type": "Feature"}
# {"geometry": {"coordinates": [86.229, 25.2127], "type": "Point"}, "properties": {"timeseries": {"dates": ["2021", "2021", "2021"], "values": [0, 100, 100]}}, "type": "Feature"}
# {"geometry": {"coordinates": [-72.5748, 3.22666], "type": "Point"}, "properties": {"timeseries": {"dates": ["2021", "2021", "2021"], "values": [0, 100, 100]}}, "type": "Feature"}
# {"geometry": {"coordinates": [45.5507, 4.50621], "type": "Point"}, "properties": {"timeseries": {"dates": ["2021", "2021", "2021"], "values": [0, 100, 100]}}, "type": "Feature"}
# {"geometry": {"coordinates": [130.248, 32.777], "type": "Point"}, "properties": {"timeseries": {"dates": ["2021", "2021", "2021"], "values": [0, 100, 100]}}, "type": "Feature"}
# {"geometry": {"coordinates": [3.03921, 13.2298], "type": "Point"}, "properties": {"timeseries": {"dates": ["2021", "2021", "2021"], "values": [0, 100, 100]}}, "type": "Feature"}
# {"geometry": {"coordinates": [30.9768, 41.0954], "type": "Point"}, "properties": {"timeseries": {"dates": ["2021", "2021", "2021"], "values": [0, 100, 100]}}, "type": "Feature"}
# {"geometry": {"coordinates": [-73.0696, 18.4744], "type": "Point"}, "properties": {"timeseries": {"dates": ["2021", "2021", "2021"], "values": [0, 100, 100]}}, "type": "Feature"}
# {"geometry": {"coordinates": [2.17534, 7.4037], "type": "Point"}, "properties": {"timeseries": {"dates": ["2021", "2021", "2021"], "values": [0, 100, 100]}}, "type": "Feature"}
# {"geometry": {"coordinates": [30.0118, 12.1503], "type": "Point"}, "properties": {"timeseries": {"dates": ["2021", "2021", "2021"], "values": [0, 100, 100]}}, "type": "Feature"}
# {"geometry": {"coordinates": [-86.728, 35.8118], "type": "Point"}, "properties": {"timeseries": {"dates": ["2021", "2021", "2021"], "values": [0, 100, 100]}}, "type": "Feature"}
# {"geometry": {"coordinates": [-91.751, 30.2853], "type": "Point"}, "properties": {"timeseries": {"dates": ["2021", "2021", "2021"], "values": [0, 100, 100]}}, "type": "Feature"}
# {"geometry": {"coordinates": [-5.86629, 36.6638], "type": "Point"}, "properties": {"timeseries": {"dates": ["2021", "2021", "2021"], "values": [0, 100, 100]}}, "type": "Feature"}
# {"geometry": {"coordinates": [-75.8904, 9.00464], "type": "Point"}, "properties": {"timeseries": {"dates": ["2021", "2021", "2021"], "values": [0, 100, 100]}}, "type": "Feature"}
# {"geometry": {"coordinates": [84.1258, 19.5361], "type": "Point"}, "properties": {"timeseries": {"dates": ["2021", "2021", "2021"], "values": [0, 100, 100]}}, "type": "Feature"}
# {"geometry": {"coordinates": [87.9734, 22.3238], "type": "Point"}, "properties": {"timeseries": {"dates": ["2021", "2021", "2021"], "values": [0, 100, 100]}}, "type": "Feature"}
# {"geometry": {"coordinates": [66.9909, 25.2097], "type": "Point"}, "properties": {"timeseries": {"dates": ["2021", "2021", "2021"], "values": [0, 100, 100]}}, "type": "Feature"}
# {"geometry": {"coordinates": [18.1844, 11.7112], "type": "Point"}, "properties": {"timeseries": {"dates": ["2021", "2021", "2021"], "values": [0, 100, 100]}}, "type": "Feature"}
# {"geometry": {"coordinates": [-87.4085, 33.3824], "type": "Point"}, "properties": {"timeseries": {"dates": ["2021", "2021", "2021"], "values": [0, 100, 100]}}, "type": "Feature"}
# {"geometry": {"coordinates": [82.9876, 27.1972], "type": "Point"}, "properties": {"timeseries": {"dates": ["2021", "2021", "2021"], "values": [0, 100, 100]}}, "type": "Feature"}
# {"geometry": {"coordinates": [101.323, 17.3204], "type": "Point"}, "properties": {"timeseries": {"dates": ["2021", "2021", "2021"], "values": [0, 100, 100]}}, "type": "Feature"}
# {"geometry": {"coordinates": [-86.6291, 32.4901], "type": "Point"}, "properties": {"timeseries": {"dates": ["2021", "2021", "2021"], "values": [0, 100, 100]}}, "type": "Feature"}
# {"geometry": {"coordinates": [-100.832, 19.9508], "type": "Point"}, "properties": {"timeseries": {"dates": ["2021", "2021", "2021"], "values": [0, 100, 100]}}, "type": "Feature"}
# {"geometry": {"coordinates": [87.961, 23.7984], "type": "Point"}, "properties": {"timeseries": {"dates": ["2021", "2021", "2021"], "values": [0, 100, 100]}}, "type": "Feature"}
# {"geometry": {"coordinates": [9.3757, 44.6393], "type": "Point"}, "properties": {"timeseries": {"dates": ["2021", "2021", "2021"], "values": [0, 100, 100]}}, "type": "Feature"}

# %%
oname2 = 'data/making_a_marker_map_example_2.geojson'
os.makedirs(os.path.dirname(oname2), exist_ok=True)
with open(oname2, 'w') as f:
    json.dump(feature_collection2, f)

# %%
# Copy the data somewhere www accessible
#!scp data/making_a_marker_map_example_1.geojson timemachine2:/t/earthtime.org/app/data/making-earthtime-maps
# !scp data/making_a_marker_map_example_2.geojson /t/earthtime.org/app/data/making-earthtime-maps

# %%
# Please try to always add a layer description with minimally a brief explanation of what the visualization shows 
#  and where the data came from.
layer_description2 = "<h2>Flood Sites</h2><p>Sourced from <a href=\"https://floodobservatory.colorado.edu/Archives/\">https://floodobservatory.colorado.edu/Archives/</a></p><p>Displaying flood sites.</p>"
# Share link identifiers should be unique. Would be great if a DB just handled this... 
share_link_identifer2 = 'making_a_marker_map_example_2_' + str(random.getrandbits(16))
category2 = 'Making EarthTime Maps'
name2 = 'Flood Sites'
# This should be wherever yoou uploaded your data to
url2 = 'https://tiles.earthtime.org/making-earthtime-maps/making_a_marker_map_example_2.geojson'
layer_args2 = {
    'Enabled': 'TRUE',
    'Share link identifier': share_link_identifer2,
    'Category': category2, 
    'Name': name2, 
    'Credits': 'Dartmouth Flood Observatory', 
    'Base layer': 'mb_openplanetv1', 
    'Start date': '1985',
    'End date': '2021', 
    'URL': url2, 
    'Scaling': f'd3.scaleSqrt().domain([0,100]).range([0,10]).clamp(true)', 
    'Layer Description': layer_description2,
    'Map Type': 'marker',
    'Load Data Function': 'WebGLVectorTile2.prototype._loadGeojsonData',
    'Set Data Function': 'WebGLVectorTile2.prototype._setMarkerData',
    'Number of Attributes': '14',
    'Vertex Shader': 'WebGLVectorTile2.animatedMarkerVertexShader',
    'Fragment Shader': 'WebGLVectorTile2.markerFragmentShader',
    'Draw Function': 'WebGLVectorTile2.prototype._drawMarker', 
    'Draw Options': '{"pointSize": 10, "linewidth": 2, "mode": "disc"}',
    'Set Data Options': '{ "sizeKey": "timeseries", "fills": [[250, 242, 232, 0.55]], "strokes": [[250, 242, 232, 0.75]]}',
    'Draw Order': '700',
}
row = GoogleSheetRow(layer_args2)

# %%
# C&P the output of this into a sheet. Would be cool if this just like happened...
row.print_row()
# Out:
# TRUE	making_a_marker_map_example_2_13724	Making EarthTime Maps	Flood Sites	Dartmouth Flood Observatory	mb_openplanetv1		1985	2021		https://tiles.earthtime.org/making-earthtime-maps/making_a_marker_map_example_2.geojson	d3.scaleSqrt().domain([0,100]).range([0,10]).clamp(true)		marker															WebGLVectorTile2.prototype._loadGeojsonData	WebGLVectorTile2.prototype._setMarkerData		14	WebGLVectorTile2.animatedMarkerVertexShader	WebGLVectorTile2.markerFragmentShader	WebGLVectorTile2.prototype._drawMarker				<h2>Flood Sites</h2><p>Sourced from <a href="https://floodobservatory.colorado.edu/Archives/">https://floodobservatory.colorado.edu/Archives/</a></p><p>Displaying flood sites.</p>		{"pointSize": 10, "linewidth": 2, "mode": "disc"}	{ "sizeKey": "timeseries", "fills": [[250, 242, 232, 0.55]], "strokes": [[250, 242, 232, 0.75]]}		700
